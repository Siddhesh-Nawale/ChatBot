# %% [markdown]
# ## Import and Load data file

# %%
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle

import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.optimizers import SGD
import random

words=[]
classes = []
documents = []
ignore_words = ['?', '!']
data_file = open('intents.json').read()
intents = json.loads(data_file)

# %% [markdown]
# ## Pre-process data

# %% [markdown]
# Here we iterate through the patterns and tokenize the sentence using nltk.word_tokenize() function and append each word in the words list. We also create a list of classes for our tags.

# %%
for intent in intents['intents']:
    for pattern in intent['patterns']:

        #tokenize each word
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        #add documents in the corpus
        documents.append((w, intent['tag']))

        # add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# %% [markdown]
# lemmatize each word and remove duplicate words from the list

# %%
# lemmatize, lower each word and remove duplicates
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))
# sort classes
classes = sorted(list(set(classes)))
# documents = combination between patterns and intents
print (len(documents), "documents")
# classes = intents
print (len(classes), "classes", classes)
# words = all words, vocabulary
print (len(words), "unique lemmatized words", words)

pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))
# Out:
# 47 documents
# 9 classes ['adverse_drug', 'blood_pressure', 'blood_pressure_search', 'goodbye', 'greeting', 'hospital_search', 'options', 'pharmacy_search', 'thanks']
# 88 unique lemmatized words ["'s", ',', 'a', 'adverse', 'all', 'anyone', 'are', 'awesome', 'be', 'behavior', 'blood', 'by', 'bye', 'can', 'causing', 'chatting', 'check', 'could', 'data', 'day', 'detail', 'do', 'dont', 'drug', 'entry', 'find', 'for', 'give', 'good', 'goodbye', 'have', 'hello', 'help', 'helpful', 'helping', 'hey', 'hi', 'history', 'hola', 'hospital', 'how', 'i', 'id', 'is', 'later', 'list', 'load', 'locate', 'log', 'looking', 'lookup', 'management', 'me', 'module', 'nearby', 'next', 'nice', 'of', 'offered', 'open', 'patient', 'pharmacy', 'pressure', 'provide', 'reaction', 'related', 'result', 'search', 'searching', 'see', 'show', 'suitable', 'support', 'task', 'thank', 'thanks', 'that', 'there', 'till', 'time', 'to', 'transfer', 'up', 'want', 'what', 'which', 'with', 'you']

# %% [markdown]
# ## Create training and testing data

# %%
# create our training data
training = []
# create an empty array for our output
output_empty = [0] * len(classes)
# training set, bag of words for each sentence
for doc in documents:
    # initialize our bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    # create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)
    
    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    
    training.append([bag, output_row])
# shuffle our features and turn into np.array
random.shuffle(training)
training = np.array(training)
# create train and test lists. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data created")
# Out:
# Training data created

# %% [markdown]
# ## Create Model

# %%
# Create model - 3 layers. First layer 128 neurons, second layer 64 neurons and 3rd output layer contains number of neurons
# equal to number of intents to predict output intent with softmax
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

#fitting and saving the model 
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('chatbot_model.h5', hist)

print("model created")
# Out:
# Epoch 1/200
# 10/10 [==============================] - 0s 4ms/step - loss: 2.2287 - accuracy: 0.1277
# Epoch 2/200
# 10/10 [==============================] - 0s 2ms/step - loss: 2.1681 - accuracy: 0.2340
# Epoch 3/200
# 10/10 [==============================] - 0s 1ms/step - loss: 2.1421 - accuracy: 0.1489
# Epoch 4/200
# 10/10 [==============================] - 0s 2ms/step - loss: 2.0078 - accuracy: 0.3617
# Epoch 5/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.8981 - accuracy: 0.4255
# Epoch 6/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.8259 - accuracy: 0.4043
# Epoch 7/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.8347 - accuracy: 0.3404
# Epoch 8/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.6008 - accuracy: 0.4468
# Epoch 9/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.4279 - accuracy: 0.5957
# Epoch 10/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.3418 - accuracy: 0.4681
# Epoch 11/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.1760 - accuracy: 0.6809
# Epoch 12/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.0412 - accuracy: 0.7021
# Epoch 13/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.8726 - accuracy: 0.7872
# Epoch 14/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.9843 - accuracy: 0.6383
# Epoch 15/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.9120 - accuracy: 0.7660
# Epoch 16/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.7620 - accuracy: 0.8085
# Epoch 17/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.7199 - accuracy: 0.7447
# Epoch 18/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.8111 - accuracy: 0.7234
# Epoch 19/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6455 - accuracy: 0.7872
# Epoch 20/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.5151 - accuracy: 0.8936
# Epoch 21/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.5975 - accuracy: 0.8085
# Epoch 22/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4027 - accuracy: 0.9149
# Epoch 23/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.5582 - accuracy: 0.7660
# Epoch 24/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3170 - accuracy: 0.9149
# Epoch 25/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3896 - accuracy: 0.8936
# Epoch 26/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3200 - accuracy: 0.8936
# Epoch 27/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2434 - accuracy: 0.9787
# Epoch 28/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2813 - accuracy: 0.8936
# Epoch 29/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2069 - accuracy: 0.9574
# Epoch 30/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2063 - accuracy: 1.0000
# Epoch 31/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1785 - accuracy: 0.9787
# Epoch 32/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3343 - accuracy: 0.9149
# Epoch 33/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2273 - accuracy: 0.9787
# Epoch 34/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2303 - accuracy: 0.9362
# Epoch 35/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1504 - accuracy: 0.9787
# Epoch 36/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1597 - accuracy: 0.9574
# Epoch 37/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1732 - accuracy: 0.9574
# Epoch 38/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1974 - accuracy: 0.9149
# Epoch 39/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1233 - accuracy: 1.0000
# Epoch 40/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1306 - accuracy: 0.9787
# Epoch 41/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1172 - accuracy: 0.9787
# Epoch 42/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1546 - accuracy: 0.9574
# Epoch 43/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1101 - accuracy: 0.9574
# Epoch 44/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1176 - accuracy: 0.9787
# Epoch 45/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1117 - accuracy: 0.9574
# Epoch 46/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0448 - accuracy: 1.0000
# Epoch 47/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1090 - accuracy: 0.9574
# Epoch 48/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1252 - accuracy: 0.9787
# Epoch 49/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0427 - accuracy: 1.0000
# Epoch 50/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0808 - accuracy: 1.0000
# Epoch 51/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0988 - accuracy: 0.9787
# Epoch 52/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1016 - accuracy: 0.9787
# Epoch 53/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1377 - accuracy: 0.9574
# Epoch 54/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0610 - accuracy: 1.0000
# Epoch 55/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0878 - accuracy: 1.0000
# Epoch 56/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1135 - accuracy: 0.9787
# Epoch 57/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0805 - accuracy: 1.0000
# Epoch 58/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0954 - accuracy: 0.9787
# Epoch 59/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1515 - accuracy: 0.9574
# Epoch 60/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0774 - accuracy: 0.9787
# Epoch 61/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0570 - accuracy: 1.0000
# Epoch 62/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0769 - accuracy: 1.0000
# Epoch 63/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0796 - accuracy: 0.9574
# Epoch 64/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0769 - accuracy: 0.9574
# Epoch 65/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0681 - accuracy: 0.9787
# Epoch 66/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0556 - accuracy: 1.0000
# Epoch 67/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0794 - accuracy: 1.0000
# Epoch 68/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0427 - accuracy: 1.0000
# Epoch 69/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0879 - accuracy: 0.9787
# Epoch 70/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1052 - accuracy: 0.9574
# Epoch 71/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0590 - accuracy: 0.9787
# Epoch 72/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0729 - accuracy: 0.9787
# Epoch 73/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0340 - accuracy: 1.0000
# Epoch 74/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0889 - accuracy: 0.9787
# Epoch 75/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0413 - accuracy: 1.0000
# Epoch 76/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0542 - accuracy: 0.9787
# Epoch 77/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0750 - accuracy: 0.9787
# Epoch 78/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1481 - accuracy: 0.9574
# Epoch 79/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0864 - accuracy: 0.9574
# Epoch 80/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0746 - accuracy: 0.9787
# Epoch 81/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0897 - accuracy: 0.9787
# Epoch 82/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0281 - accuracy: 1.0000
# Epoch 83/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0603 - accuracy: 1.0000
# Epoch 84/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0256 - accuracy: 1.0000
# Epoch 85/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0563 - accuracy: 1.0000
# Epoch 86/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0624 - accuracy: 0.9787
# Epoch 87/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0546 - accuracy: 0.9787
# Epoch 88/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0308 - accuracy: 1.0000
# Epoch 89/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1611 - accuracy: 0.9362
# Epoch 90/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0350 - accuracy: 1.0000
# Epoch 91/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0238 - accuracy: 1.0000
# Epoch 92/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0200 - accuracy: 1.0000
# Epoch 93/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0637 - accuracy: 0.9787
# Epoch 94/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0220 - accuracy: 1.0000
# Epoch 95/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0135 - accuracy: 1.0000
# Epoch 96/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0364 - accuracy: 1.0000
# Epoch 97/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0402 - accuracy: 1.0000
# Epoch 98/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0251 - accuracy: 1.0000
# Epoch 99/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0493 - accuracy: 0.9787
# Epoch 100/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0545 - accuracy: 1.0000
# Epoch 101/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0121 - accuracy: 1.0000
# Epoch 102/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0138 - accuracy: 1.0000
# Epoch 103/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0106 - accuracy: 1.0000
# Epoch 104/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0285 - accuracy: 1.0000
# Epoch 105/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0455 - accuracy: 1.0000
# Epoch 106/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0765 - accuracy: 0.9787
# Epoch 107/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1036 - accuracy: 0.9787
# Epoch 108/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0147 - accuracy: 1.0000
# Epoch 109/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0140 - accuracy: 1.0000
# Epoch 110/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0300 - accuracy: 0.9787
# Epoch 111/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0253 - accuracy: 1.0000
# Epoch 112/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0292 - accuracy: 0.9787
# Epoch 113/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0207 - accuracy: 1.0000
# Epoch 114/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0355 - accuracy: 1.0000
# Epoch 115/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0412 - accuracy: 1.0000
# Epoch 116/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0230 - accuracy: 1.0000
# Epoch 117/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0358 - accuracy: 1.0000
# Epoch 118/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0826 - accuracy: 0.9574
# Epoch 119/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0294 - accuracy: 1.0000
# Epoch 120/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0077 - accuracy: 1.0000
# Epoch 121/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0984 - accuracy: 0.9574
# Epoch 122/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0549 - accuracy: 0.9787
# Epoch 123/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0732 - accuracy: 0.9574
# Epoch 124/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0273 - accuracy: 1.0000
# Epoch 125/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0384 - accuracy: 0.9787
# Epoch 126/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0309 - accuracy: 1.0000
# Epoch 127/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 1.0000
# Epoch 128/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0287 - accuracy: 0.9787
# Epoch 129/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0077 - accuracy: 1.0000
# Epoch 130/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0117 - accuracy: 1.0000
# Epoch 131/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0708 - accuracy: 0.9574
# Epoch 132/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0261 - accuracy: 1.0000
# Epoch 133/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0105 - accuracy: 1.0000
# Epoch 134/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0295 - accuracy: 1.0000
# Epoch 135/200
# 10/10 [==============================] - ETA: 0s - loss: 0.0217 - accuracy: 1.00 - 0s 2ms/step - loss: 0.0391 - accuracy: 1.0000
# Epoch 136/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0876 - accuracy: 0.9787
# Epoch 137/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0352 - accuracy: 0.9787
# Epoch 138/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0300 - accuracy: 1.0000
# Epoch 139/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0531 - accuracy: 1.0000
# Epoch 140/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0272 - accuracy: 0.9787
# Epoch 141/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0073 - accuracy: 1.0000
# Epoch 142/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0133 - accuracy: 1.0000
# Epoch 143/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0146 - accuracy: 1.0000
# Epoch 144/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0062 - accuracy: 1.0000
# Epoch 145/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0113 - accuracy: 1.0000
# Epoch 146/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0168 - accuracy: 1.0000
# Epoch 147/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0598 - accuracy: 0.9787
# Epoch 148/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0090 - accuracy: 1.0000
# Epoch 149/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0100 - accuracy: 1.0000
# Epoch 150/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 151/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 152/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0169 - accuracy: 1.0000
# Epoch 153/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0736 - accuracy: 0.9787
# Epoch 154/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0087 - accuracy: 1.0000
# Epoch 155/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0410 - accuracy: 0.9787
# Epoch 156/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0315 - accuracy: 1.0000
# Epoch 157/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0499 - accuracy: 0.9787
# Epoch 158/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0058 - accuracy: 1.0000
# Epoch 159/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0293 - accuracy: 1.0000
# Epoch 160/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0339 - accuracy: 0.9787
# Epoch 161/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0134 - accuracy: 1.0000
# Epoch 162/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0099 - accuracy: 1.0000
# Epoch 163/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0302 - accuracy: 1.0000
# Epoch 164/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0615 - accuracy: 0.9787
# Epoch 165/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0083 - accuracy: 1.0000
# Epoch 166/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0516 - accuracy: 0.9787
# Epoch 167/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0112 - accuracy: 1.0000
# Epoch 168/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0233 - accuracy: 1.0000
# Epoch 169/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0114 - accuracy: 1.0000
# Epoch 170/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0071 - accuracy: 1.0000
# Epoch 171/200
# 10/10 [==============================] - ETA: 0s - loss: 0.0295 - accuracy: 1.00 - 0s 1ms/step - loss: 0.0526 - accuracy: 0.9787
# Epoch 172/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0700 - accuracy: 0.9574
# Epoch 173/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0072 - accuracy: 1.0000
# Epoch 174/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0086 - accuracy: 1.0000
# Epoch 175/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0524 - accuracy: 1.0000
# Epoch 176/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0126 - accuracy: 1.0000
# Epoch 177/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0176 - accuracy: 1.0000
# Epoch 178/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 179/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0178 - accuracy: 1.0000
# Epoch 180/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 181/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0778 - accuracy: 0.9787
# Epoch 182/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0167 - accuracy: 1.0000
# Epoch 183/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0250 - accuracy: 1.0000
# Epoch 184/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0153 - accuracy: 1.0000
# Epoch 185/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0121 - accuracy: 1.0000
# Epoch 186/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 1.0000
# Epoch 187/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0395 - accuracy: 1.0000
# Epoch 188/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0503 - accuracy: 0.9787
# Epoch 189/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0065 - accuracy: 1.0000
# Epoch 190/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0248 - accuracy: 1.0000
# Epoch 191/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0223 - accuracy: 1.0000
# Epoch 192/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0076 - accuracy: 1.0000
# Epoch 193/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0067 - accuracy: 1.0000
# Epoch 194/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0050 - accuracy: 1.0000
# Epoch 195/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0246 - accuracy: 1.0000
# Epoch 196/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0201 - accuracy: 1.0000
# Epoch 197/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0126 - accuracy: 1.0000
# Epoch 198/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0454 - accuracy: 0.9787
# Epoch 199/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0066 - accuracy: 1.0000
# Epoch 200/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0379 - accuracy: 0.9787
# model created

# %%
from keras.models import load_model
model = load_model('chatbot_model.h5')
import json
import random
intents = json.loads(open('intents.json').read())
words = pickle.load(open('words.pkl','rb'))
classes = pickle.load(open('classes.pkl','rb'))

# %%
def clean_up_sentence(sentence):
    # tokenize the pattern - split words into array
    sentence_words = nltk.word_tokenize(sentence)
    # stem each word - create short form for word
    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words]
    return sentence_words
# return bag of words array: 0 or 1 for each word in the bag that exists in the sentence

# %%
def bow(sentence, words, show_details=True):
    # tokenize the pattern
    sentence_words = clean_up_sentence(sentence)
    # bag of words - matrix of N words, vocabulary matrix
    bag = [0]*len(words) 
    for s in sentence_words:
        for i,w in enumerate(words):
            if w == s: 
                # assign 1 if current word is in the vocabulary position
                bag[i] = 1
                if show_details:
                    print ("found in bag: %s" % w)
    return(np.array(bag))

# %%
def predict_class(sentence, model):
    # filter out predictions below a threshold
    p = bow(sentence, words,show_details=False)
    res = model.predict(np.array([p]))[0]
    ERROR_THRESHOLD = 0.25
    results = [[i,r] for i,r in enumerate(res) if r>ERROR_THRESHOLD]
    # sort by strength of probability
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})
    return return_list

# %%
def getResponse(ints, intents_json):
    tag = ints[0]['intent']
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if(i['tag']== tag):
            result = random.choice(i['responses'])
            break
    return result

# %%
def chatbot_response(text):
    ints = predict_class(text, model)
    res = getResponse(ints, intents)
    return res

# %% [markdown]
# ## GUI Interface

# %%
import tkinter
from tkinter import *


def send():
    msg = EntryBox.get("1.0",'end-1c').strip()
    EntryBox.delete("0.0",END)
    if msg != '':
        ChatLog.config(state=NORMAL)
        ChatLog.insert(END, "You: " + msg + '\n\n')
        ChatLog.config(foreground="#442265", font=("Verdana", 12 ))

        res = chatbot_response(msg)
        ChatLog.insert(END, "Bot: " + res + '\n\n')

        ChatLog.config(state=DISABLED)
        ChatLog.yview(END)
        
        
base = Tk()
base.title("Hello")
base.geometry("400x500")
base.resizable(width=FALSE, height=FALSE)


#Create Chat window
ChatLog = Text(base, bd=0, bg="white", height="8", width="50", font="Arial",)

ChatLog.config(state=DISABLED)

#Bind scrollbar to Chat window
scrollbar = Scrollbar(base, command=ChatLog.yview, cursor="heart")
ChatLog['yscrollcommand'] = scrollbar.set

#Create Button to send message
SendButton = Button(base, font=("Verdana",12,'bold'), text="Send", width="12", height=5,
                    bd=0, bg="#32de97", activebackground="#3c9d9b",fg='#ffffff',
                    command= send )

#Create the box to enter message
EntryBox = Text(base, bd=0, bg="white",width="29", height="5", font="Arial", background="#dddddd")
#EntryBox.bind("<Return>", send)


#Place all components on the screen
scrollbar.place(x=376,y=6, height=386)
ChatLog.place(x=6,y=6, height=386, width=370)
EntryBox.place(x=130, y=401, height=40, width=265)
SendButton.place(x=6, y=401, height=40)

# %%
base.mainloop()
